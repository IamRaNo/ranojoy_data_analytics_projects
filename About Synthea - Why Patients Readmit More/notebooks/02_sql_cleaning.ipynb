# %% [markdown]
# # **NOTEBOOK FOR `CLEANING` AND `AGGREGATING` THE `SYNTHEA` DATASET**
# ***
#
# ***I need to create some aggregated tables, in order to proceed in my analysis***

# %% [markdown]
# ## **Creating Connections with the database**

# %%
# %load_ext autoreload
# %autoreload 2

import os
import sys
import pandas as pd
import numpy as np
from sqlalchemy import create_engine, text
from pathlib import Path
import warnings

warnings.filterwarnings('ignore')

# %%
def get_project_root(project_name="ranojoy_data_analytics_projects"):
    current_path = Path.cwd()
    if project_name in str(current_path):
        while current_path.name != project_name:
            current_path = current_path.parent
        return current_path
    else:
        for path in current_path.rglob(project_name):
            if path.is_dir():
                return path
        raise FileNotFoundError(f"Could not find project: {project_name}")

repo_root = get_project_root()
data_path = repo_root / "About Synthea - Why Patients Readmit More"

sys.path.append(str(data_path))

import src.functions as F

# %%
engine = F.get_engine()

# %%
engine
# Out:
# Engine(mysql+pymysql://root:***@localhost:3306/synthea_medical_dataset)

# %% [markdown]
# ## **Cleaning process of the data and creating aggregated tables**

# %%
necessary_tables = ['encounters','careplans','conditions','medications','procedures','patients','providers']

# %%
F.select('encounters').head(1)
# Out:
#                                      Id               start  \
# 0  d0c40d10-8d87-447e-836e-99d26ad52ea5 2010-01-23 17:45:28
#
#                  stop                               PATIENT  \
# 0 2010-01-23 18:10:28  034e9e3b-2def-4559-bb2a-7850888ae060
#
#                            ORGANIZATION                              PROVIDER  \
# 0  e002090d-4e92-300e-b41e-7d1f21dee4c6  e6283e46-fd81-3611-9459-0edb1c3da357
#
#                                   PAYER ENCOUNTERCLASS       CODE  \
# 0  6e2f1a2d-27bd-3701-8d08-dae202c58632     ambulatory  185345009
#
#              DESCRIPTION  BASE_ENCOUNTER_COST  TOTAL_CLAIM_COST  \
# 0  Encounter for symptom               129.16            129.16
#
#    PAYER_COVERAGE  REASONCODE            REASONDESCRIPTION  duration
# 0           54.16  10509002.0  Acute bronchitis (disorder)      25.0

# %%
F.find_nulls('encounters')
# Out:
#          column_names  null_values
# 13         REASONCODE        39569
# 14  REASONDESCRIPTION        39569

# %%
# # Reforming the date values
# query = """
# update encounters
# set start = str_to_date(
#     trim(replace(replace(replace(start, '"', ''), '\r', ''), '\n', '')),
#     '%Y-%m-%dT%H:%i:%sZ'
# );
# """
# F.run(query)

# query = """
# ALTER TABLE encounters
# MODIFY start datetime;
# """
# F.run(query)

# %%
# # Reforming the date values
# query = """
# update encounters
# set stop = str_to_date(
#     trim(replace(replace(replace(stop, '"', ''), '\r', ''), '\n', '')),
#     '%Y-%m-%dT%H:%i:%sZ'
# );
# """
# F.run(query)

# query = """
# ALTER TABLE encounters
# MODIFY stop datetime;
# """
# F.run(query)

# %%
F.sql('select count(distinct code) as total_code, count(distinct description) as total_description from encounters')
# Out:
#    total_code  total_description
# 0          43                 49

# %%
F.sql('select count(distinct reasoncode) as total_code, count(distinct reasondescription) as total_description from encounters')
# Out:
#    total_code  total_description
# 0          80                 80

# %%
F.select('encounters').head(1)
# Out:
#                                      Id               start  \
# 0  d0c40d10-8d87-447e-836e-99d26ad52ea5 2010-01-23 17:45:28
#
#                  stop                               PATIENT  \
# 0 2010-01-23 18:10:28  034e9e3b-2def-4559-bb2a-7850888ae060
#
#                            ORGANIZATION                              PROVIDER  \
# 0  e002090d-4e92-300e-b41e-7d1f21dee4c6  e6283e46-fd81-3611-9459-0edb1c3da357
#
#                                   PAYER ENCOUNTERCLASS       CODE  \
# 0  6e2f1a2d-27bd-3701-8d08-dae202c58632     ambulatory  185345009
#
#              DESCRIPTION  BASE_ENCOUNTER_COST  TOTAL_CLAIM_COST  \
# 0  Encounter for symptom               129.16            129.16
#
#    PAYER_COVERAGE  REASONCODE            REASONDESCRIPTION  duration
# 0           54.16  10509002.0  Acute bronchitis (disorder)      25.0

# %%
# query = '''
#     alter table encounters
#     add column duration float
# '''
# F.run(query)

# %%
# query = '''
#     update encounters
#     set duration = timestampdiff(minute,start,stop)
# '''
# F.run(query)

# %%
F.select('encounters').head(1)
# Out:
#                                      Id               start  \
# 0  d0c40d10-8d87-447e-836e-99d26ad52ea5 2010-01-23 17:45:28
#
#                  stop                               PATIENT  \
# 0 2010-01-23 18:10:28  034e9e3b-2def-4559-bb2a-7850888ae060
#
#                            ORGANIZATION                              PROVIDER  \
# 0  e002090d-4e92-300e-b41e-7d1f21dee4c6  e6283e46-fd81-3611-9459-0edb1c3da357
#
#                                   PAYER ENCOUNTERCLASS       CODE  \
# 0  6e2f1a2d-27bd-3701-8d08-dae202c58632     ambulatory  185345009
#
#              DESCRIPTION  BASE_ENCOUNTER_COST  TOTAL_CLAIM_COST  \
# 0  Encounter for symptom               129.16            129.16
#
#    PAYER_COVERAGE  REASONCODE            REASONDESCRIPTION  duration
# 0           54.16  10509002.0  Acute bronchitis (disorder)      25.0

# %%
encounters_agg = F.sql('''
    select id as encounter,
    start,stop,patient,provider,encounterclass,base_encounter_cost,payer_coverage,duration
                       from encounters
''')

# %%
encounters_agg.head(3)
# Out:
#                               encounter               start  \
# 0  d0c40d10-8d87-447e-836e-99d26ad52ea5 2010-01-23 17:45:28
# 1  e88bc3a9-007c-405e-aabc-792a38f4aa2b 2012-01-23 17:45:28
# 2  8f104aa7-4ca9-4473-885a-bba2437df588 2001-05-01 15:02:18
#
#                  stop                               patient  \
# 0 2010-01-23 18:10:28  034e9e3b-2def-4559-bb2a-7850888ae060
# 1 2012-01-23 18:00:28  034e9e3b-2def-4559-bb2a-7850888ae060
# 2 2001-05-01 15:17:18  1d604da9-9a81-4ba9-80c2-de3375d59b40
#
#                                provider encounterclass  base_encounter_cost  \
# 0  e6283e46-fd81-3611-9459-0edb1c3da357     ambulatory               129.16
# 1  6f1d59a7-a5bd-3cf9-9671-5bad2f351c28       wellness               129.16
# 2  af01a385-31d3-3c77-8fdb-2867fe88df2f     ambulatory               129.16
#
#    payer_coverage  duration
# 0           54.16      25.0
# 1          129.16      15.0
# 2            0.00      15.0

# %% [markdown]
# ***

# %%
F.select('careplans')
# Out:
#                                      Id       START        STOP  \
# 0  d2500b8c-e830-433a-8b9d-368d30741520  2010-01-23  2012-01-23
# 1  07d9ddd8-dfa1-4e43-9bfe-39f63f4ace15  2011-05-13  2011-08-02
# 2  a3bb6e99-3b99-44b3-974c-e230b4511b5c  2011-12-31  2012-11-30
# 3  9f5284b7-425a-486a-b36e-ab818c018f2f  2016-12-29  2017-01-05
# 4  47ede16c-c216-4f81-a16b-0e858de9cdc3  2017-01-22  2017-02-12
#
#                                 PATIENT                             ENCOUNTER  \
# 0  034e9e3b-2def-4559-bb2a-7850888ae060  d0c40d10-8d87-447e-836e-99d26ad52ea5
# 1  10339b10-3cd1-4ac3-ac13-ec26728cb592  e1ab4933-07a1-49f0-b4bd-05500919061d
# 2  f5dcd418-09fe-4a2f-baa0-3da800bd8c3a  16300c56-a035-4126-a656-68c093da6dfc
# 3  034e9e3b-2def-4559-bb2a-7850888ae060  3b639086-5fbc-4720-8c31-e8c8c0f1d660
# 4  10339b10-3cd1-4ac3-ac13-ec26728cb592  4ec8d55b-05fc-42a5-bfa3-1e233874a362
#
#         CODE          DESCRIPTION   REASONCODE            REASONDESCRIPTION
# 0   53950000  Respiratory therapy   10509002.0  Acute bronchitis (disorder)
# 1   53950000  Respiratory therapy   10509002.0  Acute bronchitis (disorder)
# 2   53950000  Respiratory therapy   10509002.0  Acute bronchitis (disorder)
# 3   53950000  Respiratory therapy   10509002.0  Acute bronchitis (disorder)
# 4  225358003           Wound care  284551006.0           Laceration of foot

# %%
query = '''
    select encounter,
    min(start) as careplan_start,
    max(stop) as careplan_end,
    case when max(stop) is null then 1 else 0 end as is_ongoing_careplan,
    count(distinct code) as total_careplans
    from careplans
    group by encounter
'''
careplan_agg = F.sql(query)

# %%
careplan_agg.head(3)
# Out:
#                               encounter careplan_start careplan_end  \
# 0  000fef3b-ba44-4b01-952e-7eeb8a5732a8     1976-07-30   1976-10-05
# 1  001d66d9-b1bc-425b-a3a7-3c24de8fcb16     2010-12-29   2011-08-03
# 2  001ed2aa-e772-4407-9902-38ef70bd1a1e     2011-10-06   2011-11-05
#
#    is_ongoing_careplan  total_careplans
# 0                    0                1
# 1                    0                1
# 2                    0                1

# %% [markdown]
# ***

# %%
F.select('conditions')
# Out:
#         START        STOP                               PATIENT  \
# 0  2001-05-01        None  1d604da9-9a81-4ba9-80c2-de3375d59b40
# 1  2011-08-09  2011-08-16  8d4c4326-e9de-4f45-9a4c-f8c36bff89ae
# 2  2011-11-16  2011-11-26  8d4c4326-e9de-4f45-9a4c-f8c36bff89ae
# 3  2011-05-13  2011-05-27  10339b10-3cd1-4ac3-ac13-ec26728cb592
# 4  2011-02-06  2011-02-14  f5dcd418-09fe-4a2f-baa0-3da800bd8c3a
#
#                               ENCOUNTER       CODE  \
# 0  8f104aa7-4ca9-4473-885a-bba2437df588   40055000
# 1  9d35ec9f-352a-4629-92ef-38eae38437e7  444814009
# 2  ae7555a9-eaff-4c09-98a7-21bc6ed1b1fd  195662009
# 3  e1ab4933-07a1-49f0-b4bd-05500919061d   10509002
# 4  b8f76eba-7795-4dcd-a544-f27ac2ef3d46  195662009
#
#                           DESCRIPTION
# 0        Chronic sinusitis (disorder)
# 1          Viral sinusitis (disorder)
# 2  Acute viral pharyngitis (disorder)
# 3         Acute bronchitis (disorder)
# 4  Acute viral pharyngitis (disorder)

# %%
query = '''
    select encounter,
    min(start) as condition_start,
    max(stop) as condition_end,
    case when max(stop) is null then 1 else 0 end as is_ongoing_condition,
    count(distinct code) as total_conditions
    from conditions
    group by encounter
'''
condition_agg = F.sql(query)

# %%
condition_agg.head(3)
# Out:
#                               encounter condition_start condition_end  \
# 0  000fef3b-ba44-4b01-952e-7eeb8a5732a8      1976-07-30    1976-10-05
# 1  001d66d9-b1bc-425b-a3a7-3c24de8fcb16      2010-12-29    2011-08-03
# 2  001ed2aa-e772-4407-9902-38ef70bd1a1e      2011-10-06    2011-11-05
#
#    is_ongoing_condition  total_conditions
# 0                     0                 1
# 1                     0                 1
# 2                     0                 1

# %% [markdown]
# ***

# %%
F.select('medications').head(3)
# Out:
#                 start                stop  \
# 0 2010-05-05 00:26:23 2011-04-30 00:26:23
# 1 2011-04-30 00:26:23 2012-04-24 00:26:23
# 2 2012-04-24 00:26:23 2013-04-19 00:26:23
#
#                                 PATIENT                                 PAYER  \
# 0  8d4c4326-e9de-4f45-9a4c-f8c36bff89ae  b1c428d6-4f07-31e0-90f0-68ffa6ff8c76
# 1  8d4c4326-e9de-4f45-9a4c-f8c36bff89ae  b1c428d6-4f07-31e0-90f0-68ffa6ff8c76
# 2  8d4c4326-e9de-4f45-9a4c-f8c36bff89ae  b1c428d6-4f07-31e0-90f0-68ffa6ff8c76
#
#                               ENCOUNTER    CODE  \
# 0  1e0d6b0e-1711-4a25-99f9-b1c700c9b260  389221
# 1  6aa37300-d1b4-48e7-a2f8-5e0f70f48f38  389221
# 2  7253a9f9-6f6d-429a-926a-7b1d424eae3f  748856
#
#                        DESCRIPTION  BASE_COST  PAYER_COVERAGE  DISPENSES  \
# 0  Etonogestrel 68 MG Drug Implant     677.08             0.0         12
# 1  Etonogestrel 68 MG Drug Implant     624.09             0.0         12
# 2                  Yaz 28 Day Pack      43.32             0.0         12
#
#    TOTALCOST  REASONCODE REASONDESCRIPTION
# 0    8124.96         NaN              None
# 1    7489.08         NaN              None
# 2     519.84         NaN              None

# %%
# # Reforming the date values
# query = """
# update medications
# set start = str_to_date(
#     trim(replace(replace(replace(start, '"', ''), '\r', ''), '\n', '')),
#     '%Y-%m-%dT%H:%i:%sZ'
# );
# """
# F.run(query)

# query = """
# ALTER TABLE medications
# MODIFY start datetime;
# """
# F.run(query)

# %%
# # Reforming the date values
# query = """
# update medications
# set stop = str_to_date(
#     trim(replace(replace(replace(stop, '"', ''), '\r', ''), '\n', '')),
#     '%Y-%m-%dT%H:%i:%sZ'
# );
# """
# F.run(query)

# query = """
# ALTER TABLE medications
# MODIFY stop datetime;
# """
# F.run(query)

# %%
query = '''
    select encounter,
    min(start) as medication_start,
    max(stop) as medication_end,
    count(distinct code) as total_medicines,
    round(avg(base_cost),2) as avg_base_medicine_cost,
    round(avg(totalcost),2) as avg_total_medicine_cost,
    count(distinct reasoncode) as reasons_for_medications 
    from medications
    group by encounter;
'''
medicine_agg = F.sql(query)

# %%
medicine_agg.head(3)
# Out:
#                               encounter    medication_start  \
# 0  0000d0b7-937c-498a-9da4-32a5d29dee39 1994-09-07 04:48:12
# 1  0004e2e7-e3f2-4d25-b3eb-813710f2f9bc 2001-11-11 02:07:45
# 2  00052e41-7581-46e1-8c7f-d31bbb50ae72 2000-03-03 08:37:29
#
#        medication_end  total_medicines  avg_base_medicine_cost  \
# 0 1995-03-15 04:48:12                2                  270.56
# 1 2002-11-17 02:07:45                1                  263.49
# 2 2000-05-05 08:37:29                2                  433.29
#
#    avg_total_medicine_cost  reasons_for_medications
# 0                  1623.33                        2
# 1                  3161.88                        1
# 2                   866.59                        1

# %% [markdown]
# ***

# %%
F.select('procedures')
# Out:
#                    DATE                               PATIENT  \
# 0  2011-04-30T00:26:23Z  8d4c4326-e9de-4f45-9a4c-f8c36bff89ae
# 1  2010-07-27T12:58:08Z  10339b10-3cd1-4ac3-ac13-ec26728cb592
# 2  2010-11-20T03:04:34Z  f5dcd418-09fe-4a2f-baa0-3da800bd8c3a
# 3  2011-02-07T03:04:34Z  f5dcd418-09fe-4a2f-baa0-3da800bd8c3a
# 4  2011-04-19T03:04:34Z  f5dcd418-09fe-4a2f-baa0-3da800bd8c3a
#
#                               ENCOUNTER       CODE  \
# 0  6aa37300-d1b4-48e7-a2f8-5e0f70f48f38  169553002
# 1  dae2b7cb-1316-4b78-954f-fa610a6c6d0e  430193006
# 2  7ff86631-0378-4bfc-92ce-1edd697eb18e  430193006
# 3  b8f76eba-7795-4dcd-a544-f27ac2ef3d46  117015009
# 4  640837d9-845a-433c-9fad-47426664a69d  117015009
#
#                                DESCRIPTION  BASE_COST   REASONCODE  \
# 0  Insertion of subcutaneous contraceptive   14896.56          NaN
# 1    Medication Reconciliation (procedure)     726.51          NaN
# 2    Medication Reconciliation (procedure)     788.50          NaN
# 3               Throat culture (procedure)    2070.44  195662009.0
# 4               Throat culture (procedure)    2479.39  195662009.0
#
#                     REASONDESCRIPTION
# 0                                None
# 1                                None
# 2                                None
# 3  Acute viral pharyngitis (disorder)
# 4  Acute viral pharyngitis (disorder)

# %%
query = '''
    select encounter, 
    count(distinct code) as total_procedures,
    round(avg(base_cost),2) as avg_procedure_cost
    from procedures
    group by encounter
'''
procedure_agg = F.sql(query)

# %%
procedure_agg.head(3)
# Out:
#                               encounter  total_procedures  avg_procedure_cost
# 0  000186d2-1316-4b58-be65-272233953fcb                 5             3652.09
# 1  0002adbb-59c3-494a-bb17-0d1acc692ae8                 1            12161.14
# 2  00055b87-0a03-4ca8-a69d-924bbb84033a                 1              516.65

# %% [markdown]
# ***

# %%
F.select('patients')
# Out:
#                                      Id   BIRTHDATE DEATHDATE          SSN  \
# 0  1d604da9-9a81-4ba9-80c2-de3375d59b40  1989-05-25      None  999-76-6866
# 1  034e9e3b-2def-4559-bb2a-7850888ae060  1983-11-14      None  999-73-5361
# 2  10339b10-3cd1-4ac3-ac13-ec26728cb592  1992-06-02      None  999-27-3385
# 3  8d4c4326-e9de-4f45-9a4c-f8c36bff89ae  1978-05-27      None  999-85-4926
# 4  f5dcd418-09fe-4a2f-baa0-3da800bd8c3a  1996-10-18      None  999-60-7372
#
#      DRIVERS    PASSPORT PREFIX            FIRST           LAST SUFFIX  ...  \
# 0  S99984236  X19277260X    Mr.  José Eduardo181       Gómez206   None  ...
# 1  S99962402  X88275464X    Mr.          Milo271        Feil794   None  ...
# 2  S99972682  X73754411X    Mr.        Jayson808       Fadel536   None  ...
# 3  S99974448  X40915583X   Mrs.       Mariana775  Rutherford999   None  ...
# 4  S99915787  X86772962X    Mr.      Gregorio366         Auer97   None  ...
#
#                          BIRTHPLACE                         ADDRESS  \
# 0  Marigot  Saint Andrew Parish  DM      427 Balistreri Way Unit 19
# 1        Danvers  Massachusetts  US        422 Farrell Path Unit 69
# 2    Springfield  Massachusetts  US       1056 Harris Lane Suite 70
# 3       Yarmouth  Massachusetts  US                  999 Kuhn Forge
# 4                Patras  Achaea  GR  1050 Lindgren Extension Apt 38
#
#          CITY          STATE            COUNTY     ZIP        LAT        LON  \
# 0    Chicopee  Massachusetts    Hampden County  1013.0  42.228354 -72.562951
# 1  Somerville  Massachusetts  Middlesex County  2143.0  42.360697 -71.126531
# 2    Chicopee  Massachusetts    Hampden County  1020.0  42.181642 -72.608842
# 3      Lowell  Massachusetts  Middlesex County  1851.0  42.636143 -71.343255
# 4      Boston  Massachusetts    Suffolk County  2135.0  42.352434 -71.028610
#
#   HEALTHCARE_EXPENSES HEALTHCARE_COVERAGE
# 0           271227.08             1334.88
# 1           793946.01             3204.49
# 2           574111.90             2606.40
# 3           935630.30             8756.19
# 4           598763.07             3772.20
#
# [5 rows x 25 columns]

# %%
query = '''
    select
    id as patient_id,
    case when 
    deathdate is null then timestampdiff(year,birthdate,"2021-12-31") 
    else timestampdiff(year,birthdate,deathdate)
    end as age_as_2022,
    marital,
    race,
    ethnicity,
    gender as patient_gender
    from patients;
'''
patient_agg = F.sql(query)

# %% [markdown]
# ***

# %%
F.select('providers')
# Out:
#                                      Id                          ORGANIZATION  \
# 0  3421aa75-dec7-378d-a9e0-0bc764e4cb0d  ef58ea08-d883-3957-8300-150554edc8fb
# 1  c9b3c857-2e24-320c-a79a-87b8a60de63c  69176529-fd1f-3b3f-abce-a0a3626769eb
# 2  0359f968-d1a6-30eb-b1cc-e6cc0b4d3513  5e765f2b-e908-3888-9fc7-df2cb87beb58
# 3  446d1609-858f-3a54-8a52-0c4eacedd00e  f1fbcbfb-fcfa-3bd2-b7f4-df20f1b3c3a4
# 4  e6283e46-fd81-3611-9459-0edb1c3da357  e002090d-4e92-300e-b41e-7d1f21dee4c6
#
#                      NAME GENDER        SPECIALITY                  ADDRESS  \
# 0       Tomas436 Sauer652      M  GENERAL PRACTICE         60 HOSPITAL ROAD
# 1   Suzette512 Monahan736      F  GENERAL PRACTICE  330 MOUNT AUBURN STREET
# 2   Gaynell126 Streich926      F  GENERAL PRACTICE          211 PARK STREET
# 3  Patricia625 Salgado989      F  GENERAL PRACTICE       ONE GENERAL STREET
# 4  Jeanmarie510 Beatty507      F  GENERAL PRACTICE    1493 CAMBRIDGE STREET
#
#          CITY STATE    ZIP        LAT        LON  UTILIZATION
# 0  LEOMINSTER    MA  01453  42.520838 -71.770876         1557
# 1   CAMBRIDGE    MA  02138  42.375967 -71.118275         2296
# 2   ATTLEBORO    MA  02703  41.931653 -71.294503         2287
# 3    LAWRENCE    MA  01842  42.700273 -71.161357         1327
# 4   CAMBRIDGE    MA  02138  42.375967 -71.118275         3199

# %%
query = '''
    select id as provider_id,
    gender as provider_gender,
    utilization 
    from providers;
'''
provider_agg = F.sql(query)

# %%
encounters_agg.sample(1)
# Out:
#                                  encounter               start  \
# 3475  022ad487-e41c-43ba-90f3-eb2d6711f4d3 1998-07-19 12:55:35
#
#                     stop                               patient  \
# 3475 1998-07-19 13:38:35  e061409e-4b85-4ec1-b1f7-02677d51f763
#
#                                   provider encounterclass  \
# 3475  0a8a9359-7b33-3256-a068-b5a7d18ebe4b     ambulatory
#
#       base_encounter_cost  payer_coverage  duration
# 3475               129.16           69.16      43.0

# %% [markdown]
# ## **Viewing the aggregated tables**

# %%
agg_tables = [encounters_agg,patient_agg,careplan_agg,procedure_agg,condition_agg,medicine_agg,provider_agg]

# %%
for table in agg_tables:
    display(table.sample(3))
# Out:
#                                   encounter               start  \
# 2862   1eda4b69-550e-481c-b23a-60e9f2a9fd49 2012-10-22 17:24:07
# 30274  9bfe0480-137b-4b8e-a014-d5d15ee177b5 1999-06-08 23:35:03
# 45855  496c0fc5-782a-496a-a0a8-1ac36f6a7d1a 1974-11-26 09:30:42
#
#                      stop                               patient  \
# 2862  2012-10-22 18:24:07  ed5cc81e-619f-471d-aee6-2934124c58e4
# 30274 1999-06-09 02:50:03  cae10920-f977-48b4-a0d3-4d70ad561fd1
# 45855 1974-11-26 12:45:42  19d2cfb8-439b-454a-b47e-5274c219005b
#
#                                    provider encounterclass  \
# 2862   de75d491-eca3-343c-90a0-a32824647526     ambulatory
# 30274  8f9aea5b-fd01-37c0-8931-18b6d64bdae6     ambulatory
# 45855  793c18cd-8269-387d-b998-c135459e4248     ambulatory
#
#        base_encounter_cost  payer_coverage  duration
# 2862                129.16           69.16      60.0
# 30274               129.16           89.16     195.0
# 45855               129.16            0.00     195.0
#                                 patient_id  age_as_2022 marital   race  \
# 1157  d9988dce-ec05-4138-8f04-b0c77473a260            4    None  white
# 149   4a52ea9c-d410-4b78-a4da-6053e2ed0787           47       M  black
# 1076  c518f618-304a-4153-af34-b11caaa566bd           43       M  white
#
#         ethnicity patient_gender
# 1157  nonhispanic              M
# 149   nonhispanic              F
# 1076  nonhispanic              F
#                                  encounter careplan_start careplan_end  \
# 2611  bf31f1f4-a0fd-4d3f-839d-9217af8ee02f     1949-06-15         None
# 2964  d8e07866-af2a-4874-8540-370a54857f48     2013-07-11   2013-09-25
# 808   3cdc18b9-08bf-4c9f-8d40-2984cdd43a03     2019-03-31   2019-11-16
#
#       is_ongoing_careplan  total_careplans
# 2611                    1                1
# 2964                    0                1
# 808                     0                1
#                                   encounter  total_procedures  \
# 15138  b79f3ece-e642-4099-bcf8-b2856e0be377                20
# 8365   65033b9b-af05-4bf8-93a6-a81730629ca9                 2
# 7360   58e94ba8-4560-4f4a-bad7-3e347e163ab2                 1
#
#        avg_procedure_cost
# 15138             3487.84
# 8365               516.65
# 7360               516.65
#                                  encounter condition_start condition_end  \
# 288   0a45453d-3b6a-4739-9b54-948045702fcd      2013-08-29    2013-09-12
# 5649  bb4e8bd2-5fea-4ae2-9e89-dd557730546f      2017-10-07    2017-10-21
# 5675  bc12ab28-03b1-40c3-aac7-3fe2db5ff94d      2019-05-03    2019-07-04
#
#       is_ongoing_condition  total_conditions
# 288                      0                 1
# 5649                     0                 1
# 5675                     0                 1
#                                   encounter    medication_start  \
# 2489   1776f1bd-0974-4abf-b006-4c535baa622a 2015-10-05 13:57:11
# 19117  b3044f22-bf1d-4f20-b919-e51da15ac3cf 1981-12-26 18:44:55
# 14980  8c58a192-5f7e-49c6-87b1-1a4525f51ee3 1963-11-16 22:09:56
#
#            medication_end  total_medicines  avg_base_medicine_cost  \
# 2489  2015-11-02 13:57:11                5                  282.72
# 19117 1983-01-01 18:44:55                4                  134.01
# 14980 1964-11-21 22:09:56                1                  263.49
#
#        avg_total_medicine_cost  reasons_for_medications
# 2489                    282.72                        2
# 19117                  1532.69                        1
# 14980                  3161.88                        1
#                                provider_id provider_gender  utilization
# 4514  33739d2c-d387-33d6-b47e-8537235ed2ca               F            0
# 5656  b2a312b9-5e6d-30a2-9bb8-6bf80903c0b8               M            0
# 4716  cd798b8b-6341-317c-9b3b-580fac1ff542               F            0

# %%
encounters_agg.columns = encounters_agg.columns.str.lower()

# %%
encounters_agg.rename(columns={'patient':'patient_id','provider':'provider_id'},inplace=True)

# %% [markdown]
# ## **Forming the aggregated dataset**

# %%
data = (encounters_agg.merge(procedure_agg,on='encounter',how='left')
    .merge(medicine_agg,on='encounter',how='left')
    .merge(condition_agg,on='encounter',how='left')
    .merge(careplan_agg,on='encounter',how='left')
    .merge(patient_agg,on='patient_id',how='left')
    .merge(provider_agg,on='provider_id',how='left'))

# %%
pd.set_option('display.max_columns',None)

# %%
data.head()
# Out:
#                               encounter               start  \
# 0  d0c40d10-8d87-447e-836e-99d26ad52ea5 2010-01-23 17:45:28
# 1  e88bc3a9-007c-405e-aabc-792a38f4aa2b 2012-01-23 17:45:28
# 2  8f104aa7-4ca9-4473-885a-bba2437df588 2001-05-01 15:02:18
# 3  b85c339a-6076-43ed-b9d0-9cf013dec49d 2011-07-28 15:02:18
# 4  dae2b7cb-1316-4b78-954f-fa610a6c6d0e 2010-07-27 12:58:08
#
#                  stop                            patient_id  \
# 0 2010-01-23 18:10:28  034e9e3b-2def-4559-bb2a-7850888ae060
# 1 2012-01-23 18:00:28  034e9e3b-2def-4559-bb2a-7850888ae060
# 2 2001-05-01 15:17:18  1d604da9-9a81-4ba9-80c2-de3375d59b40
# 3 2011-07-28 15:17:18  1d604da9-9a81-4ba9-80c2-de3375d59b40
# 4 2010-07-27 13:28:08  10339b10-3cd1-4ac3-ac13-ec26728cb592
#
#                             provider_id encounterclass  base_encounter_cost  \
# 0  e6283e46-fd81-3611-9459-0edb1c3da357     ambulatory               129.16
# 1  6f1d59a7-a5bd-3cf9-9671-5bad2f351c28       wellness               129.16
# 2  af01a385-31d3-3c77-8fdb-2867fe88df2f     ambulatory               129.16
# 3  bb17e691-262b-3546-93d5-d88e7de93246       wellness               129.16
# 4  7ed6b84a-b847-3744-9d42-15c42297a0c2       wellness               129.16
#
#    payer_coverage  duration  total_procedures  avg_procedure_cost  \
# 0           54.16      25.0               NaN                 NaN
# 1          129.16      15.0               NaN                 NaN
# 2            0.00      15.0               NaN                 NaN
# 3            0.00      15.0               NaN                 NaN
# 4          129.16      30.0               1.0              726.51
#
#   medication_start medication_end  total_medicines  avg_base_medicine_cost  \
# 0              NaT            NaT              NaN                     NaN
# 1              NaT            NaT              NaN                     NaN
# 2              NaT            NaT              NaN                     NaN
# 3              NaT            NaT              NaN                     NaN
# 4              NaT            NaT              NaN                     NaN
#
#    avg_total_medicine_cost  reasons_for_medications condition_start  \
# 0                      NaN                      NaN             NaN
# 1                      NaN                      NaN             NaN
# 2                      NaN                      NaN      2001-05-01
# 3                      NaN                      NaN             NaN
# 4                      NaN                      NaN             NaN
#
#   condition_end  is_ongoing_condition  total_conditions careplan_start  \
# 0           NaN                   NaN               NaN     2010-01-23
# 1           NaN                   NaN               NaN            NaN
# 2          None                   1.0               1.0            NaN
# 3           NaN                   NaN               NaN            NaN
# 4           NaN                   NaN               NaN            NaN
#
#   careplan_end  is_ongoing_careplan  total_careplans  age_as_2022 marital  \
# 0   2012-01-23                  0.0              1.0           38       M
# 1          NaN                  NaN              NaN           38       M
# 2          NaN                  NaN              NaN           32       M
# 3          NaN                  NaN              NaN           32       M
# 4          NaN                  NaN              NaN           29       M
#
#     race    ethnicity patient_gender provider_gender  utilization
# 0  white  nonhispanic              M               F         3199
# 1  white  nonhispanic              M               F           33
# 2  white     hispanic              M               M         2585
# 3  white     hispanic              M               F           58
# 4  white  nonhispanic              M               M           59

# %% [markdown]
# ## **Cleaning the aggregated data**

# %%
# 1. PREPARE DATA (NO COPY)
data['start'] = pd.to_datetime(data['start'])
data = data.sort_values(['patient_id', 'start'])

# 2. SELF-MERGE USING data
dup = data.merge(
    data,
    on='patient_id',
    how='inner',
    suffixes=('_first', '_second')
)

# 3. FILTER A → B WITHIN 30 DAYS
dup = dup[
    (dup['start_second'] > dup['start_first']) &
    (dup['start_second'] <= dup['start_first'] + pd.Timedelta(days=30))
]

# 4. ADD COLUMN DIRECTLY TO data
data['caused_readmission'] = 0
data.loc[data['encounter'].isin(dup['encounter_first']), 'caused_readmission'] = 1

# %%
data.sample(1)
# Out:
#                                   encounter               start  \
# 32749  4e5a9349-de4a-4520-941b-07de7d5b34a2 2005-06-09 21:09:07
#
#                      stop                            patient_id  \
# 32749 2005-06-09 21:24:07  e47e6347-73d4-4244-b92e-8a7cea33d434
#
#                                 provider_id encounterclass  \
# 32749  aa89beb2-7bc6-35fa-83f7-4b32039e84eb     outpatient
#
#        base_encounter_cost  payer_coverage  duration  total_procedures  \
# 32749               129.16             0.0      15.0               NaN
#
#        avg_procedure_cost    medication_start      medication_end  \
# 32749                 NaN 2005-06-09 21:09:07 2005-06-23 21:09:07
#
#        total_medicines  avg_base_medicine_cost  avg_total_medicine_cost  \
# 32749              2.0                   15.54                    15.54
#
#        reasons_for_medications condition_start condition_end  \
# 32749                      0.0      2005-06-09    2005-07-22
#
#        is_ongoing_condition  total_conditions careplan_start careplan_end  \
# 32749                   0.0               1.0            NaN          NaN
#
#        is_ongoing_careplan  total_careplans  age_as_2022 marital   race  \
# 32749                  NaN              NaN            1    None  white
#
#          ethnicity patient_gender provider_gender  utilization  \
# 32749  nonhispanic              M               M         1999
#
#        caused_readmission
# 32749                   0

# %%
data.rename(columns={'start':'encounter_start','stop':'encounter_finish'},inplace=True)

# %%
data.sample(1)
# Out:
#                                   encounter     encounter_start  \
# 15682  ef08f50c-1e4e-411b-800c-354882cca0b5 2020-04-18 09:55:43
#
#          encounter_finish                            patient_id  \
# 15682 2020-04-18 13:10:43  3f336702-bf73-4fc8-bd59-3ba77fd65d0d
#
#                                 provider_id encounterclass  \
# 15682  8f9aea5b-fd01-37c0-8931-18b6d64bdae6     ambulatory
#
#        base_encounter_cost  payer_coverage  duration  total_procedures  \
# 15682               129.16           89.16     195.0               1.0
#
#        avg_procedure_cost    medication_start      medication_end  \
# 15682              516.65 2020-04-18 09:55:43 2020-04-18 09:55:43
#
#        total_medicines  avg_base_medicine_cost  avg_total_medicine_cost  \
# 15682              1.0                  263.49                   263.49
#
#        reasons_for_medications condition_start condition_end  \
# 15682                      1.0             NaN           NaN
#
#        is_ongoing_condition  total_conditions careplan_start careplan_end  \
# 15682                   NaN               NaN            NaN          NaN
#
#        is_ongoing_careplan  total_careplans  age_as_2022 marital   race  \
# 15682                  NaN              NaN           98       S  white
#
#          ethnicity patient_gender provider_gender  utilization  \
# 15682  nonhispanic              M               F         4828
#
#        caused_readmission
# 15682                   1

# %%
data.isnull().sum()[data.isnull().sum()>0].reset_index(name = 'null_counts')
# Out:
#                       index  null_counts
# 0          total_procedures        32274
# 1        avg_procedure_cost        32274
# 2          medication_start        26077
# 3            medication_end        27309
# 4           total_medicines        26077
# 5    avg_base_medicine_cost        26077
# 6   avg_total_medicine_cost        26077
# 7   reasons_for_medications        26077
# 8           condition_start        45696
# 9             condition_end        48884
# 10     is_ongoing_condition        45696
# 11         total_conditions        45696
# 12           careplan_start        49874
# 13             careplan_end        51395
# 14      is_ongoing_careplan        49874
# 15          total_careplans        49874
# 16                  marital         9718

# %%
data.columns
# Out:
# Index(['encounter', 'encounter_start', 'encounter_finish', 'patient_id',
#        'provider_id', 'encounterclass', 'base_encounter_cost',
#        'payer_coverage', 'duration', 'total_procedures', 'avg_procedure_cost',
#        'medication_start', 'medication_end', 'total_medicines',
#        'avg_base_medicine_cost', 'avg_total_medicine_cost',
#        'reasons_for_medications', 'condition_start', 'condition_end',
#        'is_ongoing_condition', 'total_conditions', 'careplan_start',
#        'careplan_end', 'is_ongoing_careplan', 'total_careplans', 'age_as_2022',
#        'marital', 'race', 'ethnicity', 'patient_gender', 'provider_gender',
#        'utilization', 'caused_readmission'],
#       dtype='object')

# %%
data[['total_procedures', 'avg_procedure_cost', 'total_medicines',
       'avg_base_medicine_cost', 'avg_total_medicine_cost',
       'reasons_for_medications', 'total_conditions', 'total_careplans']] = data[['total_procedures', 'avg_procedure_cost', 'total_medicines',
       'avg_base_medicine_cost', 'avg_total_medicine_cost',
       'reasons_for_medications', 'total_conditions', 'total_careplans']].fillna(0)

# %%
data[['marital']] =data[['marital']].fillna('unknown')

# %%
data[['is_ongoing_condition', 'is_ongoing_careplan']] = data[['is_ongoing_condition', 'is_ongoing_careplan']].fillna(-1)

# %%
data.isnull().sum()[data.isnull().sum()>0].reset_index(name = 'null_counts')
# Out:
#               index  null_counts
# 0  medication_start        26077
# 1    medication_end        27309
# 2   condition_start        45696
# 3     condition_end        48884
# 4    careplan_start        49874
# 5      careplan_end        51395

# %%
data['marital']=np.where(data['marital'] =='M','MARRIED',np.where(data['marital']=='S','SINGLE','UNKNOWN'))

# %%
data['encounterclass']=data['encounterclass'].apply(lambda x: x.upper())

# %%
data.head()
# Out:
#                                   encounter     encounter_start  \
# 34106  6b5bfe89-1c58-42e8-87c4-847b542d5f0b 2010-11-09 15:06:37
# 34107  e0a65c0f-fa38-46aa-bd00-60f4473230e2 2011-11-15 15:06:37
# 34108  187f0326-5342-4b78-8818-db5418f9300b 2012-08-03 15:06:37
# 34109  ce150f69-e3a6-4793-95b6-243f754723c3 2012-10-14 15:06:37
# 34110  e905ce81-d1da-46ac-a0fb-c16bce2c77b7 2012-11-20 15:06:37
#
#          encounter_finish                            patient_id  \
# 34106 2010-11-09 15:36:37  00185faa-2760-4218-9bf5-db301acf8274
# 34107 2011-11-15 15:21:37  00185faa-2760-4218-9bf5-db301acf8274
# 34108 2012-08-03 15:36:37  00185faa-2760-4218-9bf5-db301acf8274
# 34109 2012-10-14 15:21:37  00185faa-2760-4218-9bf5-db301acf8274
# 34110 2012-11-20 15:36:37  00185faa-2760-4218-9bf5-db301acf8274
#
#                                 provider_id encounterclass  \
# 34106  fe3d1004-b6e9-3fd8-bab5-8ba4cf7d7d95       WELLNESS
# 34107  fe3d1004-b6e9-3fd8-bab5-8ba4cf7d7d95       WELLNESS
# 34108  b08f34d7-3c08-35b9-a2ba-b823511ebc57     AMBULATORY
# 34109  b08f34d7-3c08-35b9-a2ba-b823511ebc57     AMBULATORY
# 34110  fe3d1004-b6e9-3fd8-bab5-8ba4cf7d7d95       WELLNESS
#
#        base_encounter_cost  payer_coverage  duration  total_procedures  \
# 34106               129.16          129.16      30.0               1.0
# 34107               129.16          129.16      15.0               0.0
# 34108               129.16           54.16      30.0               1.0
# 34109               129.16           54.16      15.0               0.0
# 34110               129.16          129.16      30.0               1.0
#
#        avg_procedure_cost    medication_start      medication_end  \
# 34106              648.01                 NaT                 NaT
# 34107                0.00                 NaT                 NaT
# 34108             2230.40                 NaT                 NaT
# 34109                0.00 2012-10-14 15:06:37 2012-10-25 15:06:37
# 34110              590.58                 NaT                 NaT
#
#        total_medicines  avg_base_medicine_cost  avg_total_medicine_cost  \
# 34106              0.0                    0.00                     0.00
# 34107              0.0                    0.00                     0.00
# 34108              0.0                    0.00                     0.00
# 34109              1.0                   20.48                    20.48
# 34110              0.0                    0.00                     0.00
#
#        reasons_for_medications condition_start condition_end  \
# 34106                      0.0             NaN           NaN
# 34107                      0.0             NaN           NaN
# 34108                      0.0      2012-08-03    2012-08-11
# 34109                      1.0      2012-10-14    2012-10-25
# 34110                      0.0             NaN           NaN
#
#        is_ongoing_condition  total_conditions careplan_start careplan_end  \
# 34106                  -1.0               0.0            NaN          NaN
# 34107                  -1.0               0.0            NaN          NaN
# 34108                   0.0               1.0            NaN          NaN
# 34109                   0.0               1.0            NaN          NaN
# 34110                  -1.0               0.0            NaN          NaN
#
#        is_ongoing_careplan  total_careplans  age_as_2022  marital   race  \
# 34106                 -1.0              0.0           18  UNKNOWN  white
# 34107                 -1.0              0.0           18  UNKNOWN  white
# 34108                 -1.0              0.0           18  UNKNOWN  white
# 34109                 -1.0              0.0           18  UNKNOWN  white
# 34110                 -1.0              0.0           18  UNKNOWN  white
#
#          ethnicity patient_gender provider_gender  utilization  \
# 34106  nonhispanic              M               M           25
# 34107  nonhispanic              M               M           25
# 34108  nonhispanic              M               M         1616
# 34109  nonhispanic              M               M         1616
# 34110  nonhispanic              M               M           25
#
#        caused_readmission
# 34106                   0
# 34107                   0
# 34108                   0
# 34109                   0
# 34110                   0

# %%
data['race']=data['race'].apply(lambda x: x.upper())

# %%
data['ethnicity']=data['ethnicity'].apply(lambda x: x.upper())

# %%
data.head()
# Out:
#                                   encounter     encounter_start  \
# 34106  6b5bfe89-1c58-42e8-87c4-847b542d5f0b 2010-11-09 15:06:37
# 34107  e0a65c0f-fa38-46aa-bd00-60f4473230e2 2011-11-15 15:06:37
# 34108  187f0326-5342-4b78-8818-db5418f9300b 2012-08-03 15:06:37
# 34109  ce150f69-e3a6-4793-95b6-243f754723c3 2012-10-14 15:06:37
# 34110  e905ce81-d1da-46ac-a0fb-c16bce2c77b7 2012-11-20 15:06:37
#
#          encounter_finish                            patient_id  \
# 34106 2010-11-09 15:36:37  00185faa-2760-4218-9bf5-db301acf8274
# 34107 2011-11-15 15:21:37  00185faa-2760-4218-9bf5-db301acf8274
# 34108 2012-08-03 15:36:37  00185faa-2760-4218-9bf5-db301acf8274
# 34109 2012-10-14 15:21:37  00185faa-2760-4218-9bf5-db301acf8274
# 34110 2012-11-20 15:36:37  00185faa-2760-4218-9bf5-db301acf8274
#
#                                 provider_id encounterclass  \
# 34106  fe3d1004-b6e9-3fd8-bab5-8ba4cf7d7d95       WELLNESS
# 34107  fe3d1004-b6e9-3fd8-bab5-8ba4cf7d7d95       WELLNESS
# 34108  b08f34d7-3c08-35b9-a2ba-b823511ebc57     AMBULATORY
# 34109  b08f34d7-3c08-35b9-a2ba-b823511ebc57     AMBULATORY
# 34110  fe3d1004-b6e9-3fd8-bab5-8ba4cf7d7d95       WELLNESS
#
#        base_encounter_cost  payer_coverage  duration  total_procedures  \
# 34106               129.16          129.16      30.0               1.0
# 34107               129.16          129.16      15.0               0.0
# 34108               129.16           54.16      30.0               1.0
# 34109               129.16           54.16      15.0               0.0
# 34110               129.16          129.16      30.0               1.0
#
#        avg_procedure_cost    medication_start      medication_end  \
# 34106              648.01                 NaT                 NaT
# 34107                0.00                 NaT                 NaT
# 34108             2230.40                 NaT                 NaT
# 34109                0.00 2012-10-14 15:06:37 2012-10-25 15:06:37
# 34110              590.58                 NaT                 NaT
#
#        total_medicines  avg_base_medicine_cost  avg_total_medicine_cost  \
# 34106              0.0                    0.00                     0.00
# 34107              0.0                    0.00                     0.00
# 34108              0.0                    0.00                     0.00
# 34109              1.0                   20.48                    20.48
# 34110              0.0                    0.00                     0.00
#
#        reasons_for_medications condition_start condition_end  \
# 34106                      0.0             NaN           NaN
# 34107                      0.0             NaN           NaN
# 34108                      0.0      2012-08-03    2012-08-11
# 34109                      1.0      2012-10-14    2012-10-25
# 34110                      0.0             NaN           NaN
#
#        is_ongoing_condition  total_conditions careplan_start careplan_end  \
# 34106                  -1.0               0.0            NaN          NaN
# 34107                  -1.0               0.0            NaN          NaN
# 34108                   0.0               1.0            NaN          NaN
# 34109                   0.0               1.0            NaN          NaN
# 34110                  -1.0               0.0            NaN          NaN
#
#        is_ongoing_careplan  total_careplans  age_as_2022  marital   race  \
# 34106                 -1.0              0.0           18  UNKNOWN  WHITE
# 34107                 -1.0              0.0           18  UNKNOWN  WHITE
# 34108                 -1.0              0.0           18  UNKNOWN  WHITE
# 34109                 -1.0              0.0           18  UNKNOWN  WHITE
# 34110                 -1.0              0.0           18  UNKNOWN  WHITE
#
#          ethnicity patient_gender provider_gender  utilization  \
# 34106  NONHISPANIC              M               M           25
# 34107  NONHISPANIC              M               M           25
# 34108  NONHISPANIC              M               M         1616
# 34109  NONHISPANIC              M               M         1616
# 34110  NONHISPANIC              M               M           25
#
#        caused_readmission
# 34106                   0
# 34107                   0
# 34108                   0
# 34109                   0
# 34110                   0

# %%
data['condition_duration']=pd.to_datetime(data['condition_end']) - pd.to_datetime(data['condition_start'])

# %%
data['careplan_duration']=pd.to_datetime(data['careplan_end']) - pd.to_datetime(data['careplan_start'])

# %%
data.sample(5)
# Out:
#                                   encounter     encounter_start  \
# 42260  22e5b709-d95e-43ad-9bd6-cb97e9444bfd 2017-12-11 13:57:11
# 29050  9d7d094f-101f-4c65-b15c-31b0ffc589ad 1997-06-08 19:05:21
# 27491  348813de-b2dd-4bb4-a286-40b0c0c10f10 2020-01-24 11:29:41
# 32224  f522f250-10aa-4578-ba25-149ed036fe1c 2019-04-02 15:32:23
# 7933   942b73c2-52f6-463b-8496-f59c384e64a6 2014-07-08 11:02:40
#
#          encounter_finish                            patient_id  \
# 42260 2017-12-11 14:12:11  3acf9313-1874-4dff-ab2a-3187516d92d6
# 29050 1997-06-08 19:35:21  b48a38ae-3bb7-4e52-add7-bce581c87262
# 27491 2020-01-24 11:59:41  c8c1bcb3-f787-4d53-9e3f-8fc59740daa3
# 32224 2019-04-02 16:26:23  199946d9-69de-43e1-9ce6-d6b646b84955
# 7933  2014-07-08 12:02:40  a27da6fe-7844-4205-a84f-6db17bfb8935
#
#                                 provider_id encounterclass  \
# 42260  98a31629-e9a3-304d-a821-ebb8d085c535     URGENTCARE
# 29050  5ed457ac-0af4-3c3c-b230-a1b78319191b       WELLNESS
# 27491  6456aace-c722-3675-9122-3c36e4488388       WELLNESS
# 32224  56c64467-dd8a-36ca-91c5-4c729475aa21     AMBULATORY
# 7933   006bcb89-50e6-382f-8784-3cdf167ccbde      EMERGENCY
#
#        base_encounter_cost  payer_coverage  duration  total_procedures  \
# 42260               129.16            0.00      15.0               1.0
# 29050               129.16           89.16      30.0               1.0
# 27491               129.16          129.16      30.0               1.0
# 32224               129.16           59.16      54.0               1.0
# 7933                129.16           69.16      60.0               0.0
#
#        avg_procedure_cost    medication_start      medication_end  \
# 42260            27610.50                 NaT                 NaT
# 29050              509.98                 NaT                 NaT
# 27491              401.49                 NaT                 NaT
# 32224              516.65 2019-04-02 15:32:23                 NaT
# 7933                 0.00 2014-07-08 11:02:40 2014-07-29 11:02:40
#
#        total_medicines  avg_base_medicine_cost  avg_total_medicine_cost  \
# 42260              0.0                    0.00                     0.00
# 29050              0.0                    0.00                     0.00
# 27491              0.0                    0.00                     0.00
# 32224              2.0                  173.55                  2256.15
# 7933               1.0                    8.49                     8.49
#
#        reasons_for_medications condition_start condition_end  \
# 42260                      0.0             NaN           NaN
# 29050                      0.0             NaN           NaN
# 27491                      0.0             NaN           NaN
# 32224                      0.0             NaN           NaN
# 7933                       0.0      2014-07-08    2014-07-29
#
#        is_ongoing_condition  total_conditions careplan_start careplan_end  \
# 42260                  -1.0               0.0            NaN          NaN
# 29050                  -1.0               0.0            NaN          NaN
# 27491                  -1.0               0.0            NaN          NaN
# 32224                  -1.0               0.0            NaN          NaN
# 7933                    0.0               1.0            NaN          NaN
#
#        is_ongoing_careplan  total_careplans  age_as_2022  marital   race  \
# 42260                 -1.0              0.0          100  MARRIED  WHITE
# 29050                 -1.0              0.0           87  MARRIED  WHITE
# 27491                 -1.0              0.0            4  UNKNOWN  ASIAN
# 32224                 -1.0              0.0            4  UNKNOWN  WHITE
# 7933                  -1.0              0.0           62  MARRIED  ASIAN
#
#          ethnicity patient_gender provider_gender  utilization  \
# 42260  NONHISPANIC              M               F          742
# 29050  NONHISPANIC              M               M           77
# 27491  NONHISPANIC              F               F           61
# 32224  NONHISPANIC              F               F         1682
# 7933   NONHISPANIC              M               F          590
#
#        caused_readmission condition_duration careplan_duration
# 42260                   1                NaT               NaT
# 29050                   0                NaT               NaT
# 27491                   0                NaT               NaT
# 32224                   1                NaT               NaT
# 7933                    0            21 days               NaT

# %%
data.rename(columns={'duration':'encounter_duration'},inplace =True)

# %%
data[['total_procedures','total_medicines','reasons_for_medications','is_ongoing_condition','total_conditions','is_ongoing_careplan','total_careplans']] =data[['total_procedures','total_medicines','reasons_for_medications','is_ongoing_condition','total_conditions','is_ongoing_careplan','total_careplans']].astype('Int64')

# %%
data.head()
# Out:
#                                   encounter     encounter_start  \
# 34106  6b5bfe89-1c58-42e8-87c4-847b542d5f0b 2010-11-09 15:06:37
# 34107  e0a65c0f-fa38-46aa-bd00-60f4473230e2 2011-11-15 15:06:37
# 34108  187f0326-5342-4b78-8818-db5418f9300b 2012-08-03 15:06:37
# 34109  ce150f69-e3a6-4793-95b6-243f754723c3 2012-10-14 15:06:37
# 34110  e905ce81-d1da-46ac-a0fb-c16bce2c77b7 2012-11-20 15:06:37
#
#          encounter_finish                            patient_id  \
# 34106 2010-11-09 15:36:37  00185faa-2760-4218-9bf5-db301acf8274
# 34107 2011-11-15 15:21:37  00185faa-2760-4218-9bf5-db301acf8274
# 34108 2012-08-03 15:36:37  00185faa-2760-4218-9bf5-db301acf8274
# 34109 2012-10-14 15:21:37  00185faa-2760-4218-9bf5-db301acf8274
# 34110 2012-11-20 15:36:37  00185faa-2760-4218-9bf5-db301acf8274
#
#                                 provider_id encounterclass  \
# 34106  fe3d1004-b6e9-3fd8-bab5-8ba4cf7d7d95       WELLNESS
# 34107  fe3d1004-b6e9-3fd8-bab5-8ba4cf7d7d95       WELLNESS
# 34108  b08f34d7-3c08-35b9-a2ba-b823511ebc57     AMBULATORY
# 34109  b08f34d7-3c08-35b9-a2ba-b823511ebc57     AMBULATORY
# 34110  fe3d1004-b6e9-3fd8-bab5-8ba4cf7d7d95       WELLNESS
#
#        base_encounter_cost  payer_coverage  encounter_duration  \
# 34106               129.16          129.16                30.0
# 34107               129.16          129.16                15.0
# 34108               129.16           54.16                30.0
# 34109               129.16           54.16                15.0
# 34110               129.16          129.16                30.0
#
#        total_procedures  avg_procedure_cost    medication_start  \
# 34106                 1              648.01                 NaT
# 34107                 0                0.00                 NaT
# 34108                 1             2230.40                 NaT
# 34109                 0                0.00 2012-10-14 15:06:37
# 34110                 1              590.58                 NaT
#
#            medication_end  total_medicines  avg_base_medicine_cost  \
# 34106                 NaT                0                    0.00
# 34107                 NaT                0                    0.00
# 34108                 NaT                0                    0.00
# 34109 2012-10-25 15:06:37                1                   20.48
# 34110                 NaT                0                    0.00
#
#        avg_total_medicine_cost  reasons_for_medications condition_start  \
# 34106                     0.00                        0             NaN
# 34107                     0.00                        0             NaN
# 34108                     0.00                        0      2012-08-03
# 34109                    20.48                        1      2012-10-14
# 34110                     0.00                        0             NaN
#
#       condition_end  is_ongoing_condition  total_conditions careplan_start  \
# 34106           NaN                    -1                 0            NaN
# 34107           NaN                    -1                 0            NaN
# 34108    2012-08-11                     0                 1            NaN
# 34109    2012-10-25                     0                 1            NaN
# 34110           NaN                    -1                 0            NaN
#
#       careplan_end  is_ongoing_careplan  total_careplans  age_as_2022  \
# 34106          NaN                   -1                0           18
# 34107          NaN                   -1                0           18
# 34108          NaN                   -1                0           18
# 34109          NaN                   -1                0           18
# 34110          NaN                   -1                0           18
#
#        marital   race    ethnicity patient_gender provider_gender  \
# 34106  UNKNOWN  WHITE  NONHISPANIC              M               M
# 34107  UNKNOWN  WHITE  NONHISPANIC              M               M
# 34108  UNKNOWN  WHITE  NONHISPANIC              M               M
# 34109  UNKNOWN  WHITE  NONHISPANIC              M               M
# 34110  UNKNOWN  WHITE  NONHISPANIC              M               M
#
#        utilization  caused_readmission condition_duration careplan_duration
# 34106           25                   0                NaT               NaT
# 34107           25                   0                NaT               NaT
# 34108         1616                   0             8 days               NaT
# 34109         1616                   0            11 days               NaT
# 34110           25                   0                NaT               NaT

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 53346 entries, 34106 to 37567
# Data columns (total 35 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   encounter                53346 non-null  object
#  1   encounter_start          53346 non-null  datetime64[ns]
#  2   encounter_finish         53346 non-null  datetime64[ns]
#  3   patient_id               53346 non-null  object
#  4   provider_id              53346 non-null  object
#  5   encounterclass           53346 non-null  object
#  6   base_encounter_cost      53346 non-null  float64
#  7   payer_coverage           53346 non-null  float64
#  8   encounter_duration       53346 non-null  float64
#  9   total_procedures         53346 non-null  Int64
#  10  avg_procedure_cost       53346 non-null  float64
#  11  medication_start         27269 non-null  datetime64[ns]
#  12  medication_end           26037 non-null  datetime64[ns]
#  13  total_medicines          53346 non-null  Int64
#  14  avg_base_medicine_cost   53346 non-null  float64
#  15  avg_total_medicine_cost  53346 non-null  float64
#  16  reasons_for_medications  53346 non-null  Int64
#  17  condition_start          7650 non-null   object
#  18  condition_end            4462 non-null   object
#  19  is_ongoing_condition     53346 non-null  Int64
#  20  total_conditions         53346 non-null  Int64
#  21  careplan_start           3472 non-null   object
#  22  careplan_end             1951 non-null   object
#  23  is_ongoing_careplan      53346 non-null  Int64
#  24  total_careplans          53346 non-null  Int64
#  25  age_as_2022              53346 non-null  int64
#  26  marital                  53346 non-null  object
#  27  race                     53346 non-null  object
#  28  ethnicity                53346 non-null  object
#  29  patient_gender           53346 non-null  object
#  30  provider_gender          53346 non-null  object
#  31  utilization              53346 non-null  int64
#  32  caused_readmission       53346 non-null  int64
#  33  condition_duration       4462 non-null   timedelta64[ns]
#  34  careplan_duration        1951 non-null   timedelta64[ns]
# dtypes: Int64(7), datetime64[ns](4), float64(6), int64(3), object(13), timedelta64[ns](2)
# memory usage: 15.0+ MB

# %%
data['patient_id'].nunique()
# Out:
# 1171

# %%
def add_readmission_gap(df):
    df = df.sort_values(by=['patient_id', 'encounter_start'])
    df['next_admission_date'] = df.groupby('patient_id')['encounter_start'].shift(-1)
    df['days_to_readmission'] = (df['next_admission_date'] - df['encounter_finish']).dt.days
    
    return df

# %%
data = add_readmission_gap(data)

# %%
data.head(3)
# Out:
#                                   encounter     encounter_start  \
# 34106  6b5bfe89-1c58-42e8-87c4-847b542d5f0b 2010-11-09 15:06:37
# 34107  e0a65c0f-fa38-46aa-bd00-60f4473230e2 2011-11-15 15:06:37
# 34108  187f0326-5342-4b78-8818-db5418f9300b 2012-08-03 15:06:37
#
#          encounter_finish                            patient_id  \
# 34106 2010-11-09 15:36:37  00185faa-2760-4218-9bf5-db301acf8274
# 34107 2011-11-15 15:21:37  00185faa-2760-4218-9bf5-db301acf8274
# 34108 2012-08-03 15:36:37  00185faa-2760-4218-9bf5-db301acf8274
#
#                                 provider_id encounterclass  \
# 34106  fe3d1004-b6e9-3fd8-bab5-8ba4cf7d7d95       WELLNESS
# 34107  fe3d1004-b6e9-3fd8-bab5-8ba4cf7d7d95       WELLNESS
# 34108  b08f34d7-3c08-35b9-a2ba-b823511ebc57     AMBULATORY
#
#        base_encounter_cost  payer_coverage  encounter_duration  \
# 34106               129.16          129.16                30.0
# 34107               129.16          129.16                15.0
# 34108               129.16           54.16                30.0
#
#        total_procedures  avg_procedure_cost medication_start medication_end  \
# 34106                 1              648.01              NaT            NaT
# 34107                 0                0.00              NaT            NaT
# 34108                 1             2230.40              NaT            NaT
#
#        total_medicines  avg_base_medicine_cost  avg_total_medicine_cost  \
# 34106                0                     0.0                      0.0
# 34107                0                     0.0                      0.0
# 34108                0                     0.0                      0.0
#
#        reasons_for_medications condition_start condition_end  \
# 34106                        0             NaN           NaN
# 34107                        0             NaN           NaN
# 34108                        0      2012-08-03    2012-08-11
#
#        is_ongoing_condition  total_conditions careplan_start careplan_end  \
# 34106                    -1                 0            NaN          NaN
# 34107                    -1                 0            NaN          NaN
# 34108                     0                 1            NaN          NaN
#
#        is_ongoing_careplan  total_careplans  age_as_2022  marital   race  \
# 34106                   -1                0           18  UNKNOWN  WHITE
# 34107                   -1                0           18  UNKNOWN  WHITE
# 34108                   -1                0           18  UNKNOWN  WHITE
#
#          ethnicity patient_gender provider_gender  utilization  \
# 34106  NONHISPANIC              M               M           25
# 34107  NONHISPANIC              M               M           25
# 34108  NONHISPANIC              M               M         1616
#
#        caused_readmission condition_duration careplan_duration  \
# 34106                   0                NaT               NaT
# 34107                   0                NaT               NaT
# 34108                   0             8 days               NaT
#
#       next_admission_date  days_to_readmission
# 34106 2011-11-15 15:06:37                370.0
# 34107 2012-08-03 15:06:37                261.0
# 34108 2012-10-14 15:06:37                 71.0

# %%
def add_visit_number(df):
    data = df.copy()
    data = data.sort_values(by=['patient_id', 'encounter_start'])
    data['visit_number'] = data.groupby('patient_id').cumcount() + 1
    
    return data

# %%
data = add_visit_number(data)

# %%
def add_coverage_ratio(df):
    data = df.copy()
    
    # Avoid division by zero
    data['coverage_ratio'] = data.apply(
        lambda x: x['payer_coverage'] / x['base_encounter_cost'] 
        if x['base_encounter_cost'] > 0 else 0.0, 
        axis=1
    )
    
    data['coverage_ratio'] = data['coverage_ratio'].clip(upper=1.0)
    
    return data

# %%
data = add_coverage_ratio(data)

# %%
data.sample(5)
# Out:
#                                   encounter     encounter_start  \
# 7441   867f9383-aba6-4b78-b482-ddc098d03174 2016-02-04 08:16:44
# 15093  ec9ee4f4-007c-49c9-ba7d-1808388a8f1c 2016-07-23 09:55:43
# 15909  f0495d4c-9153-46b3-a743-3be2f46c0d14 2013-04-19 11:02:24
# 13684  892c9538-9d1f-4a60-bc35-edd0e1e858f6 2011-10-26 15:17:08
# 35555  2acc0c7e-02b4-4f7c-8b05-117edbc29839 2014-10-18 07:23:24
#
#          encounter_finish                            patient_id  \
# 7441  2016-02-04 08:46:44  8aa4df95-ae91-4b6a-809e-85aa89e09b4c
# 15093 2016-07-23 12:10:43  3f336702-bf73-4fc8-bd59-3ba77fd65d0d
# 15909 2013-04-19 11:17:24  0ba90366-87ad-4f9d-9bcd-c11e63eb6f27
# 13684 2011-10-26 16:02:08  9ec4030b-2529-4647-b325-b04c6b44874b
# 35555 2014-10-18 07:53:24  7e3becd0-0053-4d2e-b57e-075b874c32a6
#
#                                 provider_id encounterclass  \
# 7441   0047cfcf-39f7-3b2a-a9c5-310f413231c9       WELLNESS
# 15093  8f9aea5b-fd01-37c0-8931-18b6d64bdae6     AMBULATORY
# 15909  263a09d5-9e62-3bc6-8510-329ae6f78e6d       WELLNESS
# 13684  af01a385-31d3-3c77-8fdb-2867fe88df2f     AMBULATORY
# 35555  58b66cc1-2b86-377f-ad77-ad8164388e50     AMBULATORY
#
#        base_encounter_cost  payer_coverage  encounter_duration  \
# 7441                129.16          129.16                30.0
# 15093               129.16           89.16               135.0
# 15909               129.16          129.16                15.0
# 13684               129.16           59.16                45.0
# 35555               129.16           69.16                30.0
#
#        total_procedures  avg_procedure_cost    medication_start  \
# 7441                  1              876.42                 NaT
# 15093                 1              516.65 2016-07-23 09:55:43
# 15909                 0                0.00                 NaT
# 13684                 2              516.65                 NaT
# 35555                 1             1686.55                 NaT
#
#            medication_end  total_medicines  avg_base_medicine_cost  \
# 7441                  NaT                0                    0.00
# 15093 2016-07-23 09:55:43                1                  263.49
# 15909                 NaT                0                    0.00
# 13684                 NaT                0                    0.00
# 35555                 NaT                0                    0.00
#
#        avg_total_medicine_cost  reasons_for_medications condition_start  \
# 7441                      0.00                        0             NaN
# 15093                   263.49                        1             NaN
# 15909                     0.00                        0             NaN
# 13684                     0.00                        0             NaN
# 35555                     0.00                        0      2014-10-18
#
#       condition_end  is_ongoing_condition  total_conditions careplan_start  \
# 7441            NaN                    -1                 0            NaN
# 15093           NaN                    -1                 0            NaN
# 15909           NaN                    -1                 0            NaN
# 13684           NaN                    -1                 0            NaN
# 35555    2014-10-28                     0                 1            NaN
#
#       careplan_end  is_ongoing_careplan  total_careplans  age_as_2022  \
# 7441           NaN                   -1                0           19
# 15093          NaN                   -1                0           98
# 15909          NaN                   -1                0           62
# 13684          NaN                   -1                0           52
# 35555          NaN                   -1                0           22
#
#        marital   race    ethnicity patient_gender provider_gender  \
# 7441   UNKNOWN  WHITE  NONHISPANIC              M               F
# 15093   SINGLE  WHITE  NONHISPANIC              M               F
# 15909   SINGLE  WHITE  NONHISPANIC              F               M
# 13684   SINGLE  WHITE  NONHISPANIC              F               M
# 35555  UNKNOWN  WHITE  NONHISPANIC              F               F
#
#        utilization  caused_readmission condition_duration careplan_duration  \
# 7441            27                   0                NaT               NaT
# 15093         4828                   1                NaT               NaT
# 15909           51                   0                NaT               NaT
# 13684         2585                   0                NaT               NaT
# 35555         1811                   0            10 days               NaT
#
#       next_admission_date  days_to_readmission  visit_number  coverage_ratio
# 7441  2017-02-09 08:16:44                370.0             9        1.000000
# 15093 2016-07-26 09:55:43                  2.0           947        0.690307
# 15909 2014-04-25 11:02:24                370.0            17        1.000000
# 13684 2012-04-18 15:17:08                174.0             9        0.458037
# 35555 2015-01-20 07:23:24                 93.0             9        0.535460

# %%
data['medication_duration'] = (data['medication_end'] - data['medication_start']).dt.days

# %%
data.drop(columns=['encounter','encounter_start','encounter_finish','patient_id','provider_id','base_encounter_cost','payer_coverage','next_admission_date'],inplace=True)

# %%
data.head()
# Out:
#       encounterclass  encounter_duration  total_procedures  \
# 34106       WELLNESS                30.0                 1
# 34107       WELLNESS                15.0                 0
# 34108     AMBULATORY                30.0                 1
# 34109     AMBULATORY                15.0                 0
# 34110       WELLNESS                30.0                 1
#
#        avg_procedure_cost    medication_start      medication_end  \
# 34106              648.01                 NaT                 NaT
# 34107                0.00                 NaT                 NaT
# 34108             2230.40                 NaT                 NaT
# 34109                0.00 2012-10-14 15:06:37 2012-10-25 15:06:37
# 34110              590.58                 NaT                 NaT
#
#        total_medicines  avg_base_medicine_cost  avg_total_medicine_cost  \
# 34106                0                    0.00                     0.00
# 34107                0                    0.00                     0.00
# 34108                0                    0.00                     0.00
# 34109                1                   20.48                    20.48
# 34110                0                    0.00                     0.00
#
#        reasons_for_medications condition_start condition_end  \
# 34106                        0             NaN           NaN
# 34107                        0             NaN           NaN
# 34108                        0      2012-08-03    2012-08-11
# 34109                        1      2012-10-14    2012-10-25
# 34110                        0             NaN           NaN
#
#        is_ongoing_condition  total_conditions careplan_start careplan_end  \
# 34106                    -1                 0            NaN          NaN
# 34107                    -1                 0            NaN          NaN
# 34108                     0                 1            NaN          NaN
# 34109                     0                 1            NaN          NaN
# 34110                    -1                 0            NaN          NaN
#
#        is_ongoing_careplan  total_careplans  age_as_2022  marital   race  \
# 34106                   -1                0           18  UNKNOWN  WHITE
# 34107                   -1                0           18  UNKNOWN  WHITE
# 34108                   -1                0           18  UNKNOWN  WHITE
# 34109                   -1                0           18  UNKNOWN  WHITE
# 34110                   -1                0           18  UNKNOWN  WHITE
#
#          ethnicity patient_gender provider_gender  utilization  \
# 34106  NONHISPANIC              M               M           25
# 34107  NONHISPANIC              M               M           25
# 34108  NONHISPANIC              M               M         1616
# 34109  NONHISPANIC              M               M         1616
# 34110  NONHISPANIC              M               M           25
#
#        caused_readmission condition_duration careplan_duration  \
# 34106                   0                NaT               NaT
# 34107                   0                NaT               NaT
# 34108                   0             8 days               NaT
# 34109                   0            11 days               NaT
# 34110                   0                NaT               NaT
#
#        days_to_readmission  visit_number  coverage_ratio  medication_duration
# 34106                370.0             1        1.000000                  NaN
# 34107                261.0             2        1.000000                  NaN
# 34108                 71.0             3        0.419325                  NaN
# 34109                 36.0             4        0.419325                 11.0
# 34110                370.0             5        1.000000                  NaN

# %%
def clean_timedelta_columns(df):
    data = df.copy()
    
    duration_cols = ['condition_duration', 'careplan_duration', 'medication_duration']
    
    for col in duration_cols:
        if col in data.columns:
            data[col] = pd.to_timedelta(data[col], errors='coerce')
            data[col] = data[col].dt.days
            
    print("✅ Converted durations to numeric days. NaT replaced with NaN.")
    return data

# %%
data = clean_timedelta_columns(data)
# Out:
# ✅ Converted durations to numeric days. NaT replaced with NaN.

# %%
data.head()
# Out:
#       encounterclass  encounter_duration  total_procedures  \
# 34106       WELLNESS                30.0                 1
# 34107       WELLNESS                15.0                 0
# 34108     AMBULATORY                30.0                 1
# 34109     AMBULATORY                15.0                 0
# 34110       WELLNESS                30.0                 1
#
#        avg_procedure_cost    medication_start      medication_end  \
# 34106              648.01                 NaT                 NaT
# 34107                0.00                 NaT                 NaT
# 34108             2230.40                 NaT                 NaT
# 34109                0.00 2012-10-14 15:06:37 2012-10-25 15:06:37
# 34110              590.58                 NaT                 NaT
#
#        total_medicines  avg_base_medicine_cost  avg_total_medicine_cost  \
# 34106                0                    0.00                     0.00
# 34107                0                    0.00                     0.00
# 34108                0                    0.00                     0.00
# 34109                1                   20.48                    20.48
# 34110                0                    0.00                     0.00
#
#        reasons_for_medications condition_start condition_end  \
# 34106                        0             NaN           NaN
# 34107                        0             NaN           NaN
# 34108                        0      2012-08-03    2012-08-11
# 34109                        1      2012-10-14    2012-10-25
# 34110                        0             NaN           NaN
#
#        is_ongoing_condition  total_conditions careplan_start careplan_end  \
# 34106                    -1                 0            NaN          NaN
# 34107                    -1                 0            NaN          NaN
# 34108                     0                 1            NaN          NaN
# 34109                     0                 1            NaN          NaN
# 34110                    -1                 0            NaN          NaN
#
#        is_ongoing_careplan  total_careplans  age_as_2022  marital   race  \
# 34106                   -1                0           18  UNKNOWN  WHITE
# 34107                   -1                0           18  UNKNOWN  WHITE
# 34108                   -1                0           18  UNKNOWN  WHITE
# 34109                   -1                0           18  UNKNOWN  WHITE
# 34110                   -1                0           18  UNKNOWN  WHITE
#
#          ethnicity patient_gender provider_gender  utilization  \
# 34106  NONHISPANIC              M               M           25
# 34107  NONHISPANIC              M               M           25
# 34108  NONHISPANIC              M               M         1616
# 34109  NONHISPANIC              M               M         1616
# 34110  NONHISPANIC              M               M           25
#
#        caused_readmission  condition_duration  careplan_duration  \
# 34106                   0                 NaN                NaN
# 34107                   0                 NaN                NaN
# 34108                   0                 8.0                NaN
# 34109                   0                11.0                NaN
# 34110                   0                 NaN                NaN
#
#        days_to_readmission  visit_number  coverage_ratio  medication_duration
# 34106                370.0             1        1.000000                  NaN
# 34107                261.0             2        1.000000                  NaN
# 34108                 71.0             3        0.419325                  NaN
# 34109                 36.0             4        0.419325                  0.0
# 34110                370.0             5        1.000000                  NaN

# %%
def add_smart_duration(df):
    data = df.copy()
    
    cols = [('medication_start', 'medication_end', 'medication_duration'),
            ('condition_start', 'condition_end', 'condition_duration'),
            ('careplan_start', 'careplan_end', 'careplan_duration')]
            
    for start, end, duration_col in cols:
        if start in data.columns and end in data.columns:
            # Convert to datetime
            s = pd.to_datetime(data[start])
            e = pd.to_datetime(data[end])
            
            # 2. Calculate Days AND Add 1 (The "Inclusive" Rule)
            # This turns "Same Day" (0) into 1
            data[duration_col] = (e - s).dt.days + 1
            
            # 3. NOW fill the NaNs with 0
            # This ensures Healthy people stay 0, while "Same Day" people are 1
            data[duration_col] = data[duration_col].fillna(0)
            
    return data

# %%
data = add_smart_duration(data)

# %%
data.head()
# Out:
#       encounterclass  encounter_duration  total_procedures  \
# 34106       WELLNESS                30.0                 1
# 34107       WELLNESS                15.0                 0
# 34108     AMBULATORY                30.0                 1
# 34109     AMBULATORY                15.0                 0
# 34110       WELLNESS                30.0                 1
#
#        avg_procedure_cost    medication_start      medication_end  \
# 34106              648.01                 NaT                 NaT
# 34107                0.00                 NaT                 NaT
# 34108             2230.40                 NaT                 NaT
# 34109                0.00 2012-10-14 15:06:37 2012-10-25 15:06:37
# 34110              590.58                 NaT                 NaT
#
#        total_medicines  avg_base_medicine_cost  avg_total_medicine_cost  \
# 34106                0                    0.00                     0.00
# 34107                0                    0.00                     0.00
# 34108                0                    0.00                     0.00
# 34109                1                   20.48                    20.48
# 34110                0                    0.00                     0.00
#
#        reasons_for_medications condition_start condition_end  \
# 34106                        0             NaN           NaN
# 34107                        0             NaN           NaN
# 34108                        0      2012-08-03    2012-08-11
# 34109                        1      2012-10-14    2012-10-25
# 34110                        0             NaN           NaN
#
#        is_ongoing_condition  total_conditions careplan_start careplan_end  \
# 34106                    -1                 0            NaN          NaN
# 34107                    -1                 0            NaN          NaN
# 34108                     0                 1            NaN          NaN
# 34109                     0                 1            NaN          NaN
# 34110                    -1                 0            NaN          NaN
#
#        is_ongoing_careplan  total_careplans  age_as_2022  marital   race  \
# 34106                   -1                0           18  UNKNOWN  WHITE
# 34107                   -1                0           18  UNKNOWN  WHITE
# 34108                   -1                0           18  UNKNOWN  WHITE
# 34109                   -1                0           18  UNKNOWN  WHITE
# 34110                   -1                0           18  UNKNOWN  WHITE
#
#          ethnicity patient_gender provider_gender  utilization  \
# 34106  NONHISPANIC              M               M           25
# 34107  NONHISPANIC              M               M           25
# 34108  NONHISPANIC              M               M         1616
# 34109  NONHISPANIC              M               M         1616
# 34110  NONHISPANIC              M               M           25
#
#        caused_readmission  condition_duration  careplan_duration  \
# 34106                   0                 0.0                0.0
# 34107                   0                 0.0                0.0
# 34108                   0                 9.0                0.0
# 34109                   0                12.0                0.0
# 34110                   0                 0.0                0.0
#
#        days_to_readmission  visit_number  coverage_ratio  medication_duration
# 34106                370.0             1        1.000000                  0.0
# 34107                261.0             2        1.000000                  0.0
# 34108                 71.0             3        0.419325                  0.0
# 34109                 36.0             4        0.419325                 12.0
# 34110                370.0             5        1.000000                  0.0

# %%
data.drop(columns = ['medication_start','medication_end','condition_start','condition_end','careplan_start','careplan_end'],inplace = True)

# %%
data.head()
# Out:
#       encounterclass  encounter_duration  total_procedures  \
# 34106       WELLNESS                30.0                 1
# 34107       WELLNESS                15.0                 0
# 34108     AMBULATORY                30.0                 1
# 34109     AMBULATORY                15.0                 0
# 34110       WELLNESS                30.0                 1
#
#        avg_procedure_cost  total_medicines  avg_base_medicine_cost  \
# 34106              648.01                0                    0.00
# 34107                0.00                0                    0.00
# 34108             2230.40                0                    0.00
# 34109                0.00                1                   20.48
# 34110              590.58                0                    0.00
#
#        avg_total_medicine_cost  reasons_for_medications  is_ongoing_condition  \
# 34106                     0.00                        0                    -1
# 34107                     0.00                        0                    -1
# 34108                     0.00                        0                     0
# 34109                    20.48                        1                     0
# 34110                     0.00                        0                    -1
#
#        total_conditions  is_ongoing_careplan  total_careplans  age_as_2022  \
# 34106                 0                   -1                0           18
# 34107                 0                   -1                0           18
# 34108                 1                   -1                0           18
# 34109                 1                   -1                0           18
# 34110                 0                   -1                0           18
#
#        marital   race    ethnicity patient_gender provider_gender  \
# 34106  UNKNOWN  WHITE  NONHISPANIC              M               M
# 34107  UNKNOWN  WHITE  NONHISPANIC              M               M
# 34108  UNKNOWN  WHITE  NONHISPANIC              M               M
# 34109  UNKNOWN  WHITE  NONHISPANIC              M               M
# 34110  UNKNOWN  WHITE  NONHISPANIC              M               M
#
#        utilization  caused_readmission  condition_duration  careplan_duration  \
# 34106           25                   0                 0.0                0.0
# 34107           25                   0                 0.0                0.0
# 34108         1616                   0                 9.0                0.0
# 34109         1616                   0                12.0                0.0
# 34110           25                   0                 0.0                0.0
#
#        days_to_readmission  visit_number  coverage_ratio  medication_duration
# 34106                370.0             1        1.000000                  0.0
# 34107                261.0             2        1.000000                  0.0
# 34108                 71.0             3        0.419325                  0.0
# 34109                 36.0             4        0.419325                 12.0
# 34110                370.0             5        1.000000                  0.0

# %%
def add_procedures_per_hour(df):
    data = df.copy()
    
    raw_hours = data['encounter_duration'] / 60
    effective_hours = raw_hours.clip(lower=1.0)
    
    data['procedures_per_hour'] = data['total_procedures'] / effective_hours
    
    return data

# %%
data = add_procedures_per_hour(data)

# %%
data.sample(5)
# Out:
#       encounterclass  encounter_duration  total_procedures  \
# 5175      URGENTCARE                15.0                 0
# 46756     AMBULATORY                15.0                 0
# 48279      INPATIENT              1620.0                 1
# 4061        WELLNESS                15.0                 0
# 486       AMBULATORY                50.0                 1
#
#        avg_procedure_cost  total_medicines  avg_base_medicine_cost  \
# 5175                 0.00                0                    0.00
# 46756                0.00                0                    0.00
# 48279            22661.46                2                  358.52
# 4061                 0.00                0                    0.00
# 486              13035.43                0                    0.00
#
#        avg_total_medicine_cost  reasons_for_medications  is_ongoing_condition  \
# 5175                      0.00                        0                    -1
# 46756                     0.00                        0                     0
# 48279                   358.52                        1                    -1
# 4061                      0.00                        0                    -1
# 486                       0.00                        0                    -1
#
#        total_conditions  is_ongoing_careplan  total_careplans  age_as_2022  \
# 5175                  0                   -1                0           70
# 46756                 1                   -1                0           59
# 48279                 0                   -1                0           84
# 4061                  0                   -1                0           50
# 486                   0                   -1                0           62
#
#        marital   race    ethnicity patient_gender provider_gender  \
# 5175    SINGLE  WHITE  NONHISPANIC              M               F
# 46756  MARRIED  WHITE  NONHISPANIC              M               M
# 48279  MARRIED  WHITE  NONHISPANIC              M               M
# 4061   MARRIED  BLACK  NONHISPANIC              F               M
# 486    MARRIED  WHITE  NONHISPANIC              F               F
#
#        utilization  caused_readmission  condition_duration  careplan_duration  \
# 5175           420                   1                 0.0                0.0
# 46756         4466                   0                15.0                0.0
# 48279          310                   1                 0.0                0.0
# 4061            44                   0                 0.0                0.0
# 486           2159                   0                 0.0                0.0
#
#        days_to_readmission  visit_number  coverage_ratio  medication_duration  \
# 5175                  27.0           299        0.000000                  0.0
# 46756                399.0             6        0.000000                  0.0
# 48279                 23.0            81        0.690307                  1.0
# 4061                  -1.0            16        1.000000                  0.0
# 486                  267.0            65        0.419325                  0.0
#
#        procedures_per_hour
# 5175                   0.0
# 46756                  0.0
# 48279             0.037037
# 4061                   0.0
# 486                    1.0

# %%
data[['condition_duration','careplan_duration','days_to_readmission','medication_duration']] = data[['condition_duration','careplan_duration','days_to_readmission','medication_duration']].astype('Int64')

# %%
data.head()
# Out:
#       encounterclass  encounter_duration  total_procedures  \
# 34106       WELLNESS                30.0                 1
# 34107       WELLNESS                15.0                 0
# 34108     AMBULATORY                30.0                 1
# 34109     AMBULATORY                15.0                 0
# 34110       WELLNESS                30.0                 1
#
#        avg_procedure_cost  total_medicines  avg_base_medicine_cost  \
# 34106              648.01                0                    0.00
# 34107                0.00                0                    0.00
# 34108             2230.40                0                    0.00
# 34109                0.00                1                   20.48
# 34110              590.58                0                    0.00
#
#        avg_total_medicine_cost  reasons_for_medications  is_ongoing_condition  \
# 34106                     0.00                        0                    -1
# 34107                     0.00                        0                    -1
# 34108                     0.00                        0                     0
# 34109                    20.48                        1                     0
# 34110                     0.00                        0                    -1
#
#        total_conditions  is_ongoing_careplan  total_careplans  age_as_2022  \
# 34106                 0                   -1                0           18
# 34107                 0                   -1                0           18
# 34108                 1                   -1                0           18
# 34109                 1                   -1                0           18
# 34110                 0                   -1                0           18
#
#        marital   race    ethnicity patient_gender provider_gender  \
# 34106  UNKNOWN  WHITE  NONHISPANIC              M               M
# 34107  UNKNOWN  WHITE  NONHISPANIC              M               M
# 34108  UNKNOWN  WHITE  NONHISPANIC              M               M
# 34109  UNKNOWN  WHITE  NONHISPANIC              M               M
# 34110  UNKNOWN  WHITE  NONHISPANIC              M               M
#
#        utilization  caused_readmission  condition_duration  careplan_duration  \
# 34106           25                   0                   0                  0
# 34107           25                   0                   0                  0
# 34108         1616                   0                   9                  0
# 34109         1616                   0                  12                  0
# 34110           25                   0                   0                  0
#
#        days_to_readmission  visit_number  coverage_ratio  medication_duration  \
# 34106                  370             1        1.000000                    0
# 34107                  261             2        1.000000                    0
# 34108                   71             3        0.419325                    0
# 34109                   36             4        0.419325                   12
# 34110                  370             5        1.000000                    0
#
#        procedures_per_hour
# 34106                  1.0
# 34107                  0.0
# 34108                  1.0
# 34109                  0.0
# 34110                  1.0

# %%
data['coverage_ratio']= data['coverage_ratio'].round(2)

# %%
data.head()
# Out:
#       encounterclass  encounter_duration  total_procedures  \
# 34106       WELLNESS                30.0                 1
# 34107       WELLNESS                15.0                 0
# 34108     AMBULATORY                30.0                 1
# 34109     AMBULATORY                15.0                 0
# 34110       WELLNESS                30.0                 1
#
#        avg_procedure_cost  total_medicines  avg_base_medicine_cost  \
# 34106              648.01                0                    0.00
# 34107                0.00                0                    0.00
# 34108             2230.40                0                    0.00
# 34109                0.00                1                   20.48
# 34110              590.58                0                    0.00
#
#        avg_total_medicine_cost  reasons_for_medications  is_ongoing_condition  \
# 34106                     0.00                        0                    -1
# 34107                     0.00                        0                    -1
# 34108                     0.00                        0                     0
# 34109                    20.48                        1                     0
# 34110                     0.00                        0                    -1
#
#        total_conditions  is_ongoing_careplan  total_careplans  age_as_2022  \
# 34106                 0                   -1                0           18
# 34107                 0                   -1                0           18
# 34108                 1                   -1                0           18
# 34109                 1                   -1                0           18
# 34110                 0                   -1                0           18
#
#        marital   race    ethnicity patient_gender provider_gender  \
# 34106  UNKNOWN  WHITE  NONHISPANIC              M               M
# 34107  UNKNOWN  WHITE  NONHISPANIC              M               M
# 34108  UNKNOWN  WHITE  NONHISPANIC              M               M
# 34109  UNKNOWN  WHITE  NONHISPANIC              M               M
# 34110  UNKNOWN  WHITE  NONHISPANIC              M               M
#
#        utilization  caused_readmission  condition_duration  careplan_duration  \
# 34106           25                   0                   0                  0
# 34107           25                   0                   0                  0
# 34108         1616                   0                   9                  0
# 34109         1616                   0                  12                  0
# 34110           25                   0                   0                  0
#
#        days_to_readmission  visit_number  coverage_ratio  medication_duration  \
# 34106                  370             1            1.00                    0
# 34107                  261             2            1.00                    0
# 34108                   71             3            0.42                    0
# 34109                   36             4            0.42                   12
# 34110                  370             5            1.00                    0
#
#        procedures_per_hour
# 34106                  1.0
# 34107                  0.0
# 34108                  1.0
# 34109                  0.0
# 34110                  1.0

# %%
data.isnull().sum()[data.isnull().sum()>0].reset_index(name = 'null_counts')
# Out:
#                  index  null_counts
# 0  days_to_readmission         1171

# %%
data['days_to_readmission']=data['days_to_readmission'].fillna(0)

# %%
data['is_ongoing_condition']=np.where(data['is_ongoing_condition']== -1,'NO CONDITION',np.where(data['is_ongoing_condition']==0,'NO','YES'))

# %%
data['is_ongoing_careplan']=np.where(data['is_ongoing_careplan']== -1,'NO CAREPLAN',np.where(data['is_ongoing_careplan']==0,'NO','YES'))

# %%
data['caused_readmission']=np.where(data['caused_readmission'] == 1,'YES','NO')

# %%
data['procedures_per_hour']= data['procedures_per_hour'].round(2)

# %%
data.drop(columns=['days_to_readmission'],inplace=True)

# %% [markdown]
# ## **Exporting the data**

# %%
file_path = data_path / "data" / "processed_data" / "processed_synthea_data.csv"

# %%
data.to_csv(file_path,index=False)
